# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Read the input image
input_image = cv.imread('Input/brain_proton_density_slice.png', cv.IMREAD_GRAYSCALE)  


t1 = np.linspace(0,80,80)
t2 = np.linspace(81,150,0)
t3 = np.linspace(151,255,100)
t4 = np.linspace(180,255,76)
tf = np.concatenate((t1,t2,t3,t4), axis=0).astype(np.uint8)

# Create the output image
output_image = cv.LUT(input_image, tf)

# Plot the intensity transformation graph
plt.plot(range(256), t, label='Intensity Transformation')
plt.xlabel('Input Intensity') 
plt.ylabel('Output Intensity')
plt.title('Intensity Transformation Graph')
plt.show()
# Save the plot as an image
plt.savefig('intensity_transformation_graph_Q2_a.png')


# Save or display the output image
cv.imwrite('white_matter_output_Q2a.jpg', output_image)  # Save the output image
# Out:
# True

# %%
fig, ax = plt.subplots(1, 2, figsize=(6, 8))
ax[0].imshow(input_image, cmap='gray', vmin=0, vmax=255)
ax[0].set_title('Input Image')
ax[1].imshow(output_image, cmap='gray', vmin=0, vmax=255)
ax[1].set_title('Output Image')
for a in ax:
    a.axis('off')
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Read the input image
input_image = cv.imread('Input/brain_proton_density_slice.png', cv.IMREAD_GRAYSCALE)  

t1 = np.linspace(0,25,150)
t2 = np.linspace(26,255,106)
t = np.concatenate((t1,t2), axis=0).astype(np.uint8)

# Create the output image
output_image = cv.LUT(input_image, t)

# Plot the intensity transformation graph
plt.plot(range(256), t, label='Intensity Transformation')
plt.xlabel('Input Intensity')
plt.ylabel('Output Intensity')
plt.title('Intensity Transformation Graph')

# Save the plot as an image
plt.savefig('intensity_transformation_graph_Q2_b.png')


# Save or display the output image
cv.imwrite('gray_matter_output_Q2b.jpg', output_image)  # Save the output image
# Out:
# True

# %%
fig, ax = plt.subplots(1, 2, figsize=(6, 8))
ax[0].imshow(input_image, cmap='gray', vmin=0, vmax=255)
ax[0].set_title('Input Image')
ax[1].imshow(output_image, cmap='gray', vmin=0, vmax=255)
ax[1].set_title('Output Image')
for a in ax:
    a.axis('off')
plt.show()
